# %% [markdown]
# ## Pythonのバージョン確認

# %%
# Colabで実行（Jupyter Lab実行時は!を削除して実行）
# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# ## 算術計算

# %%
1 + 2
# Out:
# 3

# %%
1 - 2
# Out:
# -1

# %%
7 / 5
# Out:
# 1.4

# %%
3 ** 2
# Out:
# 9

# %% [markdown]
# ## データ型

# %%
type(10)
# Out:
# int

# %%
type(2.718)
# Out:
# float

# %%
type('10')
# Out:
# str

# %% [markdown]
# ## リスト

# %%
a = [1, 2, 3, 4, 5]
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
len(a)
# Out:
# 5

# %%
a[0]
# Out:
# 1

# %%
a[4]
# Out:
# 5

# %%
a[4] = 99

# %%
a
# Out:
# [1, 2, 3, 4, 99]

# %%
a[-1]
# Out:
# 99

# %%
a[1:4]
# Out:
# [2, 3, 4]

# %% [markdown]
# ## ディクショナリ

# %%
me = {'height':180}
me['height']
# Out:
# 180

# %%
me['weight'] = 70
print(me)
# Out:
# {'height': 180, 'weight': 70}

# %% [markdown]
# ## for文

# %%
for i in [1,2,3]:
  print(i)
# Out:
# 1
# 2
# 3
